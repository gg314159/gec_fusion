# %%
import os 
os.environ['CUDA_VISIBLE_DEVICES'] = "0" 
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import hiddenlayer as hl
import torch
import torch.nn as nn
from torch.optim import SGD,Adam
import torch.utils.data as Data
from torchvision import models
from  torchvision import transforms
from  torchvision.datasets import ImageFolder
import pickle as pkl
import torchvision.models as models
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

from datetime import datetime

# %%
# 使用预训练模型
resnet = models.resnet18(pretrained=True)


# 修改最后的全连接层改为十分类
resnet.fc = nn.Linear(512, 3)

# %%
# 查看模型一级子层个数
count = 0
for layer in resnet.children():
    count = count + 1
print(count)  # 共10个一级子层
# Out:
# 10

# %%
# 迁移学习冻结部分参数
count = 0
for layer in resnet.children():
    count = count + 1
    if count < 8:
        for param in layer.parameters():
            param.requires_grad = False  # 前9个一级子层无需参数更新
    # 最后一个(第10个)调整过输出的全连接层不冻住参数

# %%
for k, v in resnet.named_parameters():
    print("{}:参数需要计算梯度并更新吗?{}".format(k, v.requires_grad))  # False表示冻结了，True表示没有冻结
# Out:
# conv1.weight:参数需要计算梯度并更新吗?False
# bn1.weight:参数需要计算梯度并更新吗?False
# bn1.bias:参数需要计算梯度并更新吗?False
# layer1.0.conv1.weight:参数需要计算梯度并更新吗?False
# layer1.0.bn1.weight:参数需要计算梯度并更新吗?False
# layer1.0.bn1.bias:参数需要计算梯度并更新吗?False
# layer1.0.conv2.weight:参数需要计算梯度并更新吗?False
# layer1.0.bn2.weight:参数需要计算梯度并更新吗?False
# layer1.0.bn2.bias:参数需要计算梯度并更新吗?False
# layer1.1.conv1.weight:参数需要计算梯度并更新吗?False
# layer1.1.bn1.weight:参数需要计算梯度并更新吗?False
# layer1.1.bn1.bias:参数需要计算梯度并更新吗?False
# layer1.1.conv2.weight:参数需要计算梯度并更新吗?False
# layer1.1.bn2.weight:参数需要计算梯度并更新吗?False
# layer1.1.bn2.bias:参数需要计算梯度并更新吗?False
# layer2.0.conv1.weight:参数需要计算梯度并更新吗?False
# layer2.0.bn1.weight:参数需要计算梯度并更新吗?False
# layer2.0.bn1.bias:参数需要计算梯度并更新吗?False
# layer2.0.conv2.weight:参数需要计算梯度并更新吗?False
# layer2.0.bn2.weight:参数需要计算梯度并更新吗?False
# layer2.0.bn2.bias:参数需要计算梯度并更新吗?False
# layer2.0.downsample.0.weight:参数需要计算梯度并更新吗?False
# layer2.0.downsample.1.weight:参数需要计算梯度并更新吗?False
# layer2.0.downsample.1.bias:参数需要计算梯度并更新吗?False
# layer2.1.conv1.weight:参数需要计算梯度并更新吗?False
# layer2.1.bn1.weight:参数需要计算梯度并更新吗?False
# layer2.1.bn1.bias:参数需要计算梯度并更新吗?False
# layer2.1.conv2.weight:参数需要计算梯度并更新吗?False
# layer2.1.bn2.weight:参数需要计算梯度并更新吗?False
# layer2.1.bn2.bias:参数需要计算梯度并更新吗?False
# layer3.0.conv1.weight:参数需要计算梯度并更新吗?False
# layer3.0.bn1.weight:参数需要计算梯度并更新吗?False
# layer3.0.bn1.bias:参数需要计算梯度并更新吗?False
# layer3.0.conv2.weight:参数需要计算梯度并更新吗?False
# layer3.0.bn2.weight:参数需要计算梯度并更新吗?False
# layer3.0.bn2.bias:参数需要计算梯度并更新吗?False
# layer3.0.downsample.0.weight:参数需要计算梯度并更新吗?False
# layer3.0.downsample.1.weight:参数需要计算梯度并更新吗?False
# layer3.0.downsample.1.bias:参数需要计算梯度并更新吗?False
# layer3.1.conv1.weight:参数需要计算梯度并更新吗?False
# layer3.1.bn1.weight:参数需要计算梯度并更新吗?False
# layer3.1.bn1.bias:参数需要计算梯度并更新吗?False
# layer3.1.conv2.weight:参数需要计算梯度并更新吗?False
# layer3.1.bn2.weight:参数需要计算梯度并更新吗?False
# layer3.1.bn2.bias:参数需要计算梯度并更新吗?False
# layer4.0.conv1.weight:参数需要计算梯度并更新吗?True
# layer4.0.bn1.weight:参数需要计算梯度并更新吗?True
# layer4.0.bn1.bias:参数需要计算梯度并更新吗?True
# layer4.0.conv2.weight:参数需要计算梯度并更新吗?True
# layer4.0.bn2.weight:参数需要计算梯度并更新吗?True
# layer4.0.bn2.bias:参数需要计算梯度并更新吗?True
# layer4.0.downsample.0.weight:参数需要计算梯度并更新吗?True
# layer4.0.downsample.1.weight:参数需要计算梯度并更新吗?True
# layer4.0.downsample.1.bias:参数需要计算梯度并更新吗?True
# layer4.1.conv1.weight:参数需要计算梯度并更新吗?True
# layer4.1.bn1.weight:参数需要计算梯度并更新吗?True
# layer4.1.bn1.bias:参数需要计算梯度并更新吗?True
# layer4.1.conv2.weight:参数需要计算梯度并更新吗?True
# layer4.1.bn2.weight:参数需要计算梯度并更新吗?True
# layer4.1.bn2.bias:参数需要计算梯度并更新吗?True
# fc.weight:参数需要计算梯度并更新吗?True
# fc.bias:参数需要计算梯度并更新吗?True

# %%
from torch.utils.data import DataLoader
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, root,transform_pet = None):
        super(MyDataset, self).__init__()
        MRI_PET_match_all = pkl.load(open(root,"rb"),encoding='iso-8859-1')
        MRI = []
        PET = []
        group = []
        for index,row in MRI_PET_match_all.iterrows():
            MRI.append(row['MRI_img_array'])
            PET.append(row['PET_img_array'])
            group_ = torch.tensor(row['Group'],dtype=torch.int64)
            group.append(group_)
        self.MRI = MRI
        self.PET = PET
        self.group = group  
        self.transform_pet = transform_pet

    def __getitem__(self, index):
        mri =torch.from_numpy(self.MRI[index].transpose([2,0,1])).float().to(DEVICE)
        pet = torch.from_numpy(self.PET[index].transpose([2,0,1])).float().to(DEVICE)
        pet = self.transform_pet(pet)
        group = self.group[index].to(DEVICE)
        return pet,group

    def __len__(self):
        return len(self.MRI)

#not 16
# train_mean_mri = [4.1620684, 4.1620684, 4.1620684]
# train_std_mri = [5.2131376, 5.2131376, 5.2131376]
# train_mean_pet = [4.081158, 4.081158, 4.081158] 
# train_std_pet = [5.1888165, 5.1888165, 5.1888165]

# test_mean_mri = [4.1623616, 4.1623616, 4.1623616]
# test_std_mri = [5.2136188, 5.2136188, 5.2136188]
# test_mean_pet = [4.106387, 4.106387, 4.106387]
# test_std_pet = [5.18535, 5.18535, 5.18535]

#16-in-1
train_mean_mri = [4.176061, 4.176061, 4.176061]
train_std_mri = [5.231413, 5.231413, 5.231413]
train_mean_pet = [4.017313, 4.017313, 4.017313] 
train_std_pet = [5.1714053, 5.1714053, 5.1714053]

test_mean_mri = [4.3262687, 4.3262687, 4.3262687]
test_std_mri = [5.419836, 5.419836, 5.419836] 
test_mean_pet = [4.1623745, 4.1623745, 4.1623745]
test_std_pet = [5.3586817, 5.3586817, 5.3586817]

valid_mean_mri = [4.7232037, 4.7232037, 4.7232037]
valid_std_mri =  [5.8529644, 5.8529644, 5.8529644] 
valid_mean_pet = [4.5747848, 4.5747848, 4.5747848]
valid_std_pet = [5.809622, 5.809622, 5.809622]
    
train_transform_mri = transforms.Compose([
    transforms.Normalize(train_mean_mri,train_std_mri),
    transforms.RandomVerticalFlip(),
    transforms.RandomHorizontalFlip(),
    
])

train_transform_pet = transforms.Compose([
    transforms.Normalize(train_mean_pet,train_std_pet),
    transforms.RandomVerticalFlip(),
    transforms.RandomHorizontalFlip(),
])

test_transform_mri = transforms.Compose([
    
    transforms.Normalize(test_mean_mri,test_std_mri),
])

test_transform_pet = transforms.Compose([
   
    transforms.Normalize(test_mean_pet,test_std_pet)
])


train_data = MyDataset("/home/gc/gechang/gec_multi_fusion/end_to_end/train.pkl",transform_pet =train_transform_pet)
test_data = MyDataset("/home/gc/gechang/gec_multi_fusion/end_to_end/test.pkl",transform_pet =test_transform_pet)

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
test_loader = DataLoader(test_data, batch_size=32)

# %%
# 计算准确率
def get_acc(output, label):
    total = output.shape[0]
    _, pred_label = output.max(1)
    num_correct = (pred_label == label).sum().item()
    return num_correct / total

# %%
def train(net, train_data, valid_data, num_epochs, optimizer, criterion):
    prev_time = datetime.now()
    for epoch in range(num_epochs):
        train_loss = 0
        train_acc = 0
        net = net.train()
        for im, label in train_data:
            im = im.to(DEVICE)  # (bs, 3, h, w)
            label = label.to(DEVICE)  # (bs, h, w)
            # forward
            output = net(im)
            loss = criterion(output, label)
            # backward
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
 
            train_loss += loss.item()
            train_acc += get_acc(output, label)
 
        cur_time = datetime.now()
        h, remainder = divmod((cur_time - prev_time).seconds, 3600)
        m, s = divmod(remainder, 60)
        time_str = "Time %02d:%02d:%02d" % (h, m, s)
        if valid_data is not None:
            valid_loss = 0
            valid_acc = 0
            net = net.eval()
            for im, label in valid_data:
                im = im.to(DEVICE)  # (bs, 3, h, w)
                label = label.to(DEVICE)  # (bs, h, w)
                output = net(im)
                loss = criterion(output, label)
                valid_loss += loss.item()
                valid_acc += get_acc(output, label)
            epoch_str = (
                    "Epoch %d. Train Loss: %f, Train Acc: %f, Valid Loss: %f, Valid Acc: %f, "
                    % (epoch, train_loss / len(train_data),
                       train_acc / len(train_data), valid_loss / len(valid_data),
                       valid_acc / len(valid_data)))
        else:
            epoch_str = ("Epoch %d. Train Loss: %f, Train Acc: %f, " %
                         (epoch, train_loss / len(train_data),
                          train_acc / len(train_data)))
        prev_time = cur_time
        print(epoch_str + time_str)

# %%
resnet = resnet.to(DEVICE)
criterion = nn.CrossEntropyLoss()  # 损失函数
# 只需要优化最后一层参数
optimizer = torch.optim.SGD(filter(lambda p: p.requires_grad, resnet.parameters()), lr=1e-3, weight_decay=1e-3, momentum=0.9)  # 优化器

# train
train(resnet, train_loader, test_loader, 130, optimizer, criterion)
# Out:
# Epoch 0. Train Loss: 0.964457, Train Acc: 0.557931, Valid Loss: 0.973052, Valid Acc: 0.522321, Time 00:00:04
# Epoch 1. Train Loss: 0.806322, Train Acc: 0.665603, Valid Loss: 0.903139, Valid Acc: 0.580357, Time 00:00:06
# Epoch 2. Train Loss: 0.724097, Train Acc: 0.711336, Valid Loss: 0.889219, Valid Acc: 0.589286, Time 00:00:08
# Epoch 3. Train Loss: 0.653078, Train Acc: 0.740474, Valid Loss: 0.834940, Valid Acc: 0.589286, Time 00:00:08
# Epoch 4. Train Loss: 0.594379, Train Acc: 0.772586, Valid Loss: 0.824213, Valid Acc: 0.625000, Time 00:00:08
# Epoch 5. Train Loss: 0.553511, Train Acc: 0.781336, Valid Loss: 0.831803, Valid Acc: 0.629464, Time 00:00:08
# Epoch 6. Train Loss: 0.499178, Train Acc: 0.811466, Valid Loss: 0.716014, Valid Acc: 0.683036, Time 00:00:08
# Epoch 7. Train Loss: 0.449337, Train Acc: 0.850733, Valid Loss: 0.726203, Valid Acc: 0.687500, Time 00:00:07
# Epoch 8. Train Loss: 0.425154, Train Acc: 0.840733, Valid Loss: 0.707814, Valid Acc: 0.687500, Time 00:00:08
# Epoch 9. Train Loss: 0.385912, Train Acc: 0.863103, Valid Loss: 0.721796, Valid Acc: 0.691964, Time 00:00:08
# Epoch 10. Train Loss: 0.342270, Train Acc: 0.888491, Valid Loss: 0.715873, Valid Acc: 0.678571, Time 00:00:06
# Epoch 11. Train Loss: 0.281190, Train Acc: 0.907500, Valid Loss: 0.638950, Valid Acc: 0.714286, Time 00:00:05
# Epoch 12. Train Loss: 0.251965, Train Acc: 0.929224, Valid Loss: 0.642070, Valid Acc: 0.763393, Time 00:00:05
# Epoch 13. Train Loss: 0.235435, Train Acc: 0.932241, Valid Loss: 0.615699, Valid Acc: 0.745536, Time 00:00:04
# Epoch 14. Train Loss: 0.205713, Train Acc: 0.937241, Valid Loss: 0.634910, Valid Acc: 0.732143, Time 00:00:03
# Epoch 15. Train Loss: 0.170389, Train Acc: 0.959871, Valid Loss: 0.723978, Valid Acc: 0.727679, Time 00:00:06
# Epoch 16. Train Loss: 0.152659, Train Acc: 0.968750, Valid Loss: 0.593745, Valid Acc: 0.767857, Time 00:00:07
# Epoch 17. Train Loss: 0.127685, Train Acc: 0.972241, Valid Loss: 0.644642, Valid Acc: 0.750000, Time 00:00:07
# Epoch 18. Train Loss: 0.111648, Train Acc: 0.980000, Valid Loss: 0.630296, Valid Acc: 0.767857, Time 00:00:08
# Epoch 19. Train Loss: 0.102702, Train Acc: 0.980991, Valid Loss: 0.651011, Valid Acc: 0.767857, Time 00:00:07
# Epoch 20. Train Loss: 0.105367, Train Acc: 0.976121, Valid Loss: 0.628071, Valid Acc: 0.776786, Time 00:00:08
# Epoch 21. Train Loss: 0.085160, Train Acc: 0.983750, Valid Loss: 0.659622, Valid Acc: 0.785714, Time 00:00:08
# Epoch 22. Train Loss: 0.062472, Train Acc: 0.987500, Valid Loss: 0.727989, Valid Acc: 0.758929, Time 00:00:07
# Epoch 23. Train Loss: 0.065072, Train Acc: 0.984871, Valid Loss: 0.687534, Valid Acc: 0.767857, Time 00:00:08
# Epoch 24. Train Loss: 0.061082, Train Acc: 0.985000, Valid Loss: 0.644187, Valid Acc: 0.776786, Time 00:00:05
# Epoch 25. Train Loss: 0.063288, Train Acc: 0.990000, Valid Loss: 0.625952, Valid Acc: 0.785714, Time 00:00:06
# Epoch 26. Train Loss: 0.046931, Train Acc: 0.992500, Valid Loss: 0.638719, Valid Acc: 0.794643, Time 00:00:04
# Epoch 27. Train Loss: 0.041180, Train Acc: 0.996250, Valid Loss: 0.691845, Valid Acc: 0.781250, Time 00:00:05
# Epoch 28. Train Loss: 0.039389, Train Acc: 0.995000, Valid Loss: 0.764300, Valid Acc: 0.776786, Time 00:00:04
# Epoch 29. Train Loss: 0.032796, Train Acc: 0.998750, Valid Loss: 0.651380, Valid Acc: 0.781250, Time 00:00:02
# Epoch 30. Train Loss: 0.026093, Train Acc: 1.000000, Valid Loss: 0.705094, Valid Acc: 0.772321, Time 00:00:09
# Epoch 31. Train Loss: 0.038703, Train Acc: 0.995000, Valid Loss: 0.703963, Valid Acc: 0.799107, Time 00:00:08
# Epoch 32. Train Loss: 0.027532, Train Acc: 0.996250, Valid Loss: 0.704136, Valid Acc: 0.794643, Time 00:00:08
# Epoch 33. Train Loss: 0.022781, Train Acc: 0.997500, Valid Loss: 0.678992, Valid Acc: 0.794643, Time 00:00:08
# Epoch 34. Train Loss: 0.027360, Train Acc: 0.998750, Valid Loss: 0.710653, Valid Acc: 0.803571, Time 00:00:08
# Epoch 35. Train Loss: 0.026075, Train Acc: 0.996250, Valid Loss: 0.662001, Valid Acc: 0.812500, Time 00:00:09
# Epoch 36. Train Loss: 0.021755, Train Acc: 1.000000, Valid Loss: 0.684968, Valid Acc: 0.803571, Time 00:00:07
# Epoch 37. Train Loss: 0.012994, Train Acc: 1.000000, Valid Loss: 0.701610, Valid Acc: 0.790179, Time 00:00:07
# Epoch 38. Train Loss: 0.016312, Train Acc: 0.997500, Valid Loss: 0.709835, Valid Acc: 0.785714, Time 00:00:08
# Epoch 39. Train Loss: 0.014982, Train Acc: 1.000000, Valid Loss: 0.708741, Valid Acc: 0.803571, Time 00:00:04
# Epoch 40. Train Loss: 0.017204, Train Acc: 0.998750, Valid Loss: 0.693993, Valid Acc: 0.799107, Time 00:00:05
# Epoch 41. Train Loss: 0.012879, Train Acc: 0.998750, Valid Loss: 0.725983, Valid Acc: 0.772321, Time 00:00:05
# Epoch 42. Train Loss: 0.015363, Train Acc: 0.998621, Valid Loss: 0.677219, Valid Acc: 0.794643, Time 00:00:04
# Epoch 43. Train Loss: 0.013685, Train Acc: 0.998750, Valid Loss: 0.740605, Valid Acc: 0.803571, Time 00:00:03
# Epoch 44. Train Loss: 0.016405, Train Acc: 0.998750, Valid Loss: 0.784599, Valid Acc: 0.772321, Time 00:00:06
# Epoch 45. Train Loss: 0.016446, Train Acc: 0.997500, Valid Loss: 0.749615, Valid Acc: 0.803571, Time 00:00:08
# Epoch 46. Train Loss: 0.009201, Train Acc: 1.000000, Valid Loss: 0.747807, Valid Acc: 0.794643, Time 00:00:07
# Epoch 47. Train Loss: 0.008298, Train Acc: 0.998750, Valid Loss: 0.715896, Valid Acc: 0.776786, Time 00:00:08
# Epoch 48. Train Loss: 0.007569, Train Acc: 1.000000, Valid Loss: 0.708087, Valid Acc: 0.785714, Time 00:00:07
# Epoch 49. Train Loss: 0.011674, Train Acc: 0.998750, Valid Loss: 0.740355, Valid Acc: 0.781250, Time 00:00:07
# Epoch 50. Train Loss: 0.010315, Train Acc: 1.000000, Valid Loss: 0.748810, Valid Acc: 0.799107, Time 00:00:08
# Epoch 51. Train Loss: 0.007267, Train Acc: 1.000000, Valid Loss: 0.751345, Valid Acc: 0.794643, Time 00:00:08
# Epoch 52. Train Loss: 0.009109, Train Acc: 1.000000, Valid Loss: 0.732908, Valid Acc: 0.803571, Time 00:00:08
# Epoch 53. Train Loss: 0.007875, Train Acc: 0.998750, Valid Loss: 0.742190, Valid Acc: 0.803571, Time 00:00:04
# Epoch 54. Train Loss: 0.007111, Train Acc: 1.000000, Valid Loss: 0.764807, Valid Acc: 0.785714, Time 00:00:05
# Epoch 55. Train Loss: 0.010410, Train Acc: 1.000000, Valid Loss: 0.766503, Valid Acc: 0.785714, Time 00:00:05
# Epoch 56. Train Loss: 0.008811, Train Acc: 1.000000, Valid Loss: 0.753069, Valid Acc: 0.799107, Time 00:00:05
# Epoch 57. Train Loss: 0.006728, Train Acc: 1.000000, Valid Loss: 0.792220, Valid Acc: 0.799107, Time 00:00:04
# Epoch 58. Train Loss: 0.007487, Train Acc: 1.000000, Valid Loss: 0.813764, Valid Acc: 0.803571, Time 00:00:03
# Epoch 59. Train Loss: 0.006058, Train Acc: 1.000000, Valid Loss: 0.783337, Valid Acc: 0.790179, Time 00:00:09
# Epoch 60. Train Loss: 0.006032, Train Acc: 1.000000, Valid Loss: 0.805388, Valid Acc: 0.803571, Time 00:00:08
# Epoch 61. Train Loss: 0.006018, Train Acc: 1.000000, Valid Loss: 0.810702, Valid Acc: 0.790179, Time 00:00:08
# Epoch 62. Train Loss: 0.005175, Train Acc: 1.000000, Valid Loss: 0.832117, Valid Acc: 0.790179, Time 00:00:08
# Epoch 63. Train Loss: 0.005651, Train Acc: 1.000000, Valid Loss: 0.813923, Valid Acc: 0.794643, Time 00:00:08
# Epoch 64. Train Loss: 0.003803, Train Acc: 1.000000, Valid Loss: 0.802462, Valid Acc: 0.785714, Time 00:00:08
# Epoch 65. Train Loss: 0.005040, Train Acc: 1.000000, Valid Loss: 0.813112, Valid Acc: 0.808036, Time 00:00:08
# Epoch 66. Train Loss: 0.004625, Train Acc: 1.000000, Valid Loss: 0.829095, Valid Acc: 0.794643, Time 00:00:08
# Epoch 67. Train Loss: 0.005645, Train Acc: 1.000000, Valid Loss: 0.841792, Valid Acc: 0.785714, Time 00:00:04
# Epoch 68. Train Loss: 0.007639, Train Acc: 1.000000, Valid Loss: 0.813864, Valid Acc: 0.794643, Time 00:00:04
# Epoch 69. Train Loss: 0.007546, Train Acc: 1.000000, Valid Loss: 0.822656, Valid Acc: 0.803571, Time 00:00:04
# Epoch 70. Train Loss: 0.003558, Train Acc: 1.000000, Valid Loss: 0.823844, Valid Acc: 0.803571, Time 00:00:04
# Epoch 71. Train Loss: 0.006003, Train Acc: 1.000000, Valid Loss: 0.829808, Valid Acc: 0.808036, Time 00:00:04
# Epoch 72. Train Loss: 0.006283, Train Acc: 1.000000, Valid Loss: 0.852482, Valid Acc: 0.808036, Time 00:00:03
# Epoch 73. Train Loss: 0.004922, Train Acc: 1.000000, Valid Loss: 0.852901, Valid Acc: 0.794643, Time 00:00:08
# Epoch 74. Train Loss: 0.004890, Train Acc: 1.000000, Valid Loss: 0.840702, Valid Acc: 0.816964, Time 00:00:08
# Epoch 75. Train Loss: 0.004580, Train Acc: 1.000000, Valid Loss: 0.851733, Valid Acc: 0.799107, Time 00:00:08
# Epoch 76. Train Loss: 0.004576, Train Acc: 1.000000, Valid Loss: 0.882193, Valid Acc: 0.799107, Time 00:00:08
# Epoch 77. Train Loss: 0.003133, Train Acc: 1.000000, Valid Loss: 0.848310, Valid Acc: 0.803571, Time 00:00:08
# Epoch 78. Train Loss: 0.003787, Train Acc: 1.000000, Valid Loss: 0.873738, Valid Acc: 0.794643, Time 00:00:08
# Epoch 79. Train Loss: 0.003552, Train Acc: 1.000000, Valid Loss: 0.878509, Valid Acc: 0.794643, Time 00:00:08
# Epoch 80. Train Loss: 0.003740, Train Acc: 1.000000, Valid Loss: 0.881873, Valid Acc: 0.803571, Time 00:00:07
# Epoch 81. Train Loss: 0.003316, Train Acc: 1.000000, Valid Loss: 0.891959, Valid Acc: 0.799107, Time 00:00:06
# Epoch 82. Train Loss: 0.004783, Train Acc: 1.000000, Valid Loss: 0.844403, Valid Acc: 0.803571, Time 00:00:05
# Epoch 83. Train Loss: 0.004119, Train Acc: 1.000000, Valid Loss: 0.858078, Valid Acc: 0.808036, Time 00:00:04
# Epoch 84. Train Loss: 0.002420, Train Acc: 1.000000, Valid Loss: 0.864270, Valid Acc: 0.794643, Time 00:00:05
# Epoch 85. Train Loss: 0.002976, Train Acc: 1.000000, Valid Loss: 0.864119, Valid Acc: 0.799107, Time 00:00:04
# Epoch 86. Train Loss: 0.002948, Train Acc: 1.000000, Valid Loss: 0.877430, Valid Acc: 0.799107, Time 00:00:04
# Epoch 87. Train Loss: 0.002977, Train Acc: 1.000000, Valid Loss: 0.850769, Valid Acc: 0.794643, Time 00:00:08
# Epoch 88. Train Loss: 0.002386, Train Acc: 1.000000, Valid Loss: 0.854963, Valid Acc: 0.803571, Time 00:00:08
# Epoch 89. Train Loss: 0.003205, Train Acc: 1.000000, Valid Loss: 0.878920, Valid Acc: 0.803571, Time 00:00:08
# Epoch 90. Train Loss: 0.003107, Train Acc: 1.000000, Valid Loss: 0.874091, Valid Acc: 0.808036, Time 00:00:07
# Epoch 91. Train Loss: 0.004726, Train Acc: 1.000000, Valid Loss: 0.876026, Valid Acc: 0.803571, Time 00:00:07
# Epoch 92. Train Loss: 0.002507, Train Acc: 1.000000, Valid Loss: 0.897982, Valid Acc: 0.799107, Time 00:00:08
# Epoch 93. Train Loss: 0.003736, Train Acc: 1.000000, Valid Loss: 0.901244, Valid Acc: 0.799107, Time 00:00:07
# Epoch 94. Train Loss: 0.003104, Train Acc: 1.000000, Valid Loss: 0.895321, Valid Acc: 0.799107, Time 00:00:09
# Epoch 95. Train Loss: 0.003810, Train Acc: 1.000000, Valid Loss: 0.881548, Valid Acc: 0.794643, Time 00:00:05
# Epoch 96. Train Loss: 0.004533, Train Acc: 0.998750, Valid Loss: 0.885529, Valid Acc: 0.808036, Time 00:00:04
# Epoch 97. Train Loss: 0.002475, Train Acc: 1.000000, Valid Loss: 0.896059, Valid Acc: 0.808036, Time 00:00:04
# Epoch 98. Train Loss: 0.002213, Train Acc: 1.000000, Valid Loss: 0.873429, Valid Acc: 0.790179, Time 00:00:05
# Epoch 99. Train Loss: 0.002967, Train Acc: 1.000000, Valid Loss: 0.866804, Valid Acc: 0.803571, Time 00:00:04
# Epoch 100. Train Loss: 0.002133, Train Acc: 1.000000, Valid Loss: 0.887904, Valid Acc: 0.790179, Time 00:00:06
# Epoch 101. Train Loss: 0.001913, Train Acc: 1.000000, Valid Loss: 0.884859, Valid Acc: 0.794643, Time 00:00:09
# Epoch 102. Train Loss: 0.002473, Train Acc: 1.000000, Valid Loss: 0.866339, Valid Acc: 0.794643, Time 00:00:08
# Epoch 103. Train Loss: 0.002295, Train Acc: 1.000000, Valid Loss: 0.873331, Valid Acc: 0.803571, Time 00:00:10
# Epoch 104. Train Loss: 0.001724, Train Acc: 1.000000, Valid Loss: 0.902025, Valid Acc: 0.790179, Time 00:00:08
# Epoch 105. Train Loss: 0.002637, Train Acc: 1.000000, Valid Loss: 0.896990, Valid Acc: 0.794643, Time 00:00:07
# Epoch 106. Train Loss: 0.001641, Train Acc: 1.000000, Valid Loss: 0.875930, Valid Acc: 0.794643, Time 00:00:07
# Epoch 107. Train Loss: 0.002231, Train Acc: 1.000000, Valid Loss: 0.890765, Valid Acc: 0.790179, Time 00:00:07
# Epoch 108. Train Loss: 0.001542, Train Acc: 1.000000, Valid Loss: 0.906731, Valid Acc: 0.799107, Time 00:00:08
# Epoch 109. Train Loss: 0.001997, Train Acc: 1.000000, Valid Loss: 0.902506, Valid Acc: 0.794643, Time 00:00:04
# Epoch 110. Train Loss: 0.002247, Train Acc: 1.000000, Valid Loss: 0.915664, Valid Acc: 0.808036, Time 00:00:05
# Epoch 111. Train Loss: 0.002064, Train Acc: 1.000000, Valid Loss: 0.949410, Valid Acc: 0.790179, Time 00:00:05
# Epoch 112. Train Loss: 0.001502, Train Acc: 1.000000, Valid Loss: 0.920897, Valid Acc: 0.794643, Time 00:00:05
# Epoch 113. Train Loss: 0.001706, Train Acc: 1.000000, Valid Loss: 0.900707, Valid Acc: 0.803571, Time 00:00:03
# Epoch 114. Train Loss: 0.002494, Train Acc: 1.000000, Valid Loss: 0.925361, Valid Acc: 0.794643, Time 00:00:05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_246758/3781042316.py in <module>
#       5
#       6 # train
# ----> 7 train(resnet, train_loader, test_loader, 130, optimizer, criterion)
#
# /tmp/ipykernel_246758/3147887359.py in train(net, train_data, valid_data, num_epochs, optimizer, criterion)
#      16             optimizer.step()
#      17
# ---> 18             train_loss += loss.item()
#      19             train_acc += get_acc(output, label)
#      20
#
# KeyboardInterrupt:
